# %% [markdown]
# # Underfitting and Overfitting
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 의사 결정 트리를 예로 들었을 때, 트리의 깊이를 크게 할 수록 기존 데이터들을 예측하는 정확도는 높아지지만, 새로운 데이터들에 대한 예측의 정확도는 낮아진다.
# 이를 `Overfitting` 이라고 한다. 반대의 경우를 `Underfitting` 이라고 한다.
